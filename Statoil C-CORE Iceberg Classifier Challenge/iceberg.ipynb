# %% [markdown]
# # **零，連接Google Drive並設定工作目錄**

# %%
# Mask R-CNN reference code
# https://www.cnblogs.com/hellcat/p/9987442.html


# the reference web of Colab with google drive : https://www.jianshu.com/p/ce2e63d1c10c
# 戴入檔案的方式， 
# COLAB  0:從Local端的路徑  
#        1:從Google Drive 中載入 

import os
import pandas as pd
import numpy as np
import datetime
import os.path as path


IS_COLAB = 1

if IS_COLAB == 1:
  # !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
  # !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
  # !apt-get update -qq 2>&1 > /dev/null
  # !apt-get -y install -qq google-drive-ocamlfuse fuse
  from google.colab import auth
  auth.authenticate_user()
  from oauth2client.client import GoogleCredentials
  creds = GoogleCredentials.get_application_default()
  import getpass
  # !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
  vcode = getpass.getpass()
  # !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}

  # !mkdir -p drive
  # !google-drive-ocamlfuse drive

  # 此处为google drive中的文件路径,drive为之前指定的工作根目录，要加上
  os.chdir("drive/Colab Notebooks/ice berg") 
  # !ls
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 130942 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.4-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.4-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.4-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.
# drive				       ice_berg_submission_20190619_0555.csv
# iceberg_backup.ipynb		       ice_berg_submission_20190619_0602.csv
# iceberg.ipynb			       ice_berg_submission_20190623_1805.csv
# iceberg_modify.ipynb		       ice_berg_submission_20190624_0338.csv
# iceberg.png			       ice_berg_submission_20190624_0506.csv
# ice_berg_submission_20190619_0209.csv  log
# ice_berg_submission_20190619_0341.csv  test.json
# ice_berg_submission_20190619_0504.csv  train.json

# %% [markdown]
# # **一、 載入訓練資料並查看訓練資料的格式與內容**

# %%
import gc
IS_ENABLE_NORMALIZATION = True

train_data = pd.read_json("train.json")
print ("=== basic data information ===")
print (train_data.info())

print ("=== filter out the 'na' value of angle field  ===")
train_data = train_data[train_data["inc_angle"] != 'na'] 
print ("the number of train data : ", len(train_data))
iceberg_data = train_data[train_data["is_iceberg"] == 1]
print ("the number of iceberg on train data : ", len(iceberg_data))
non_iceberg_data = train_data[train_data["is_iceberg"] == 0]
print ("the number of non-iceberg on train data : ", len(non_iceberg_data))

train_dataset = iceberg_data[0:636]
train_dataset = train_dataset.append(non_iceberg_data[0:635])
print ("the number of train dataset : ", len (train_dataset))
valid_dataset = iceberg_data[636:]
valid_dataset = valid_dataset.append(non_iceberg_data[635:])
print ("the number of valid dataset : ", len (valid_dataset))
train_data.head()

del train_data
del iceberg_data
del non_iceberg_data
gc.collect()
# Out:
# === basic data information ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1604 entries, 0 to 1603
# Data columns (total 5 columns):
# band_1        1604 non-null object
# band_2        1604 non-null object
# id            1604 non-null object
# inc_angle     1604 non-null object
# is_iceberg    1604 non-null int64
# dtypes: int64(1), object(4)
# memory usage: 62.7+ KB
# None
# === filter out the 'na' value of angle field  ===
# the number of train data :  1471
# the number of iceberg on train data :  753
# the number of non-iceberg on train data :  718
# the number of train dataset :  1271
# the number of valid dataset :  200
# 7

# %%
test_data = pd.read_json("test.json")
print ("=== basic data information ===")
print (test_data.info())

print ("=== filter out the 'na' value of angle field  ===")
test_data = test_data[test_data["inc_angle"] != 'na']

print ("the count of train data : ", len(test_data))
 
test_data.head()
# Out:
# === basic data information ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8424 entries, 0 to 8423
# Data columns (total 4 columns):
# band_1       8424 non-null object
# band_2       8424 non-null object
# id           8424 non-null object
# inc_angle    8424 non-null float64
# dtypes: float64(1), object(3)
# memory usage: 263.3+ KB
# None
# === filter out the 'na' value of angle field  ===
# the count of train data :  8424
# /usr/local/lib/python3.6/dist-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
#                                               band_1  ...  inc_angle
# 0  [-15.863251, -15.201077, -17.887735, -19.17248...  ...  34.966400
# 1  [-26.058969497680664, -26.058969497680664, -26...  ...  32.615072
# 2  [-14.14109992980957, -15.064241409301758, -17....  ...  37.505433
# 3  [-12.167478, -13.706167, -16.54837, -13.572674...  ...  34.473900
# 4  [-23.37459373474121, -26.02718162536621, -28.1...  ...  43.918874
#
# [5 rows x 4 columns]

# %% [markdown]
# # **二、對訓練資料集的Band 1 及Band 2 進行資料的預處理**

# %%
import matplotlib.pyplot as plt
import numpy as np
import os, gc, psutil

IMAGE_WIDTH = 75 
IMAGE_HEIGHT = 75
DISPLAY_IMAGE = 7

def display_ice_berg(band_1, band_2, angle, is_iceberg=None, index_base=0 , suptitle = "display data image"): 
  
  fig, ax = plt.subplots(figsize=(22 , 6))
  fig.subplots_adjust(hspace=0.4, wspace=0.1)
  for i in range(DISPLAY_IMAGE):   
    plt.subplot(2, DISPLAY_IMAGE, i +1)
    if is_iceberg is None:
      plt.title("band 1 : {}".format(round(angle[i+index_base][0],8)))
    else:
      plt.title("band 1 : {}-{}".format(is_iceberg[i+index_base][0], round(angle[i+index_base][0],8)))
    plt.axis("off")
    plt.imshow(band_1[i + index_base].reshape(75,75), cmap="gray")
   
  for i in range(DISPLAY_IMAGE):     
    plt.subplot(2, DISPLAY_IMAGE, i + DISPLAY_IMAGE + 1)
    if is_iceberg is None:
      plt.title("band 2 : {}".format(round(angle[i+index_base][0],8)))
    else:
      plt.title("band 2 : {}-{}".format(is_iceberg[i+index_base][0], round(angle[i+index_base][0],8))) 
    plt.axis("off") 
    plt.suptitle(suptitle)    
    plt.imshow(band_2[i + index_base].reshape(75,75), cmap="gray")

def normalization_data(band_1, band_2, angle, is_enable):
  if is_enable:
    band_1 = (band_1 + 128) /256
    band_2 = (band_2 + 128) /256
    angle = angle /180
  return band_1, band_2, angle

# %%
# Train Data Band 1 and Band 2 Image
import gc 
print ("=== Train Dataset ===")
band_1_train_data = np.array([np.array(data).astype(np.float32).reshape(75, 75, 1) for data in train_dataset['band_1']])
print ("band 1 shape :", band_1_train_data.shape)
band_2_train_data = np.array([np.array(data).astype(np.float32).reshape(75, 75, 1) for data in train_dataset['band_2']])
print ("band 2 shape :", band_2_train_data.shape)
angle_train_data = np.array(train_dataset['inc_angle']).reshape(-1, 1)
print ("angle shape :", angle_train_data.shape)
is_iceberg_train_data = np.array(train_dataset["is_iceberg"]).reshape(-1, 1)
print ("is_iceberg shape :", is_iceberg_train_data.shape)

print ("=== Test Dataset ===")  
band_1_valid_data = np.array([np.array(data).astype(np.float32).reshape(75, 75, 1) for data in valid_dataset['band_1']])
print ("band 1 shape :", band_1_valid_data.shape)
band_2_valid_data = np.array([np.array(data).astype(np.float32).reshape(75, 75, 1) for data in valid_dataset['band_2']])
print ("band 2 shape :", band_2_valid_data.shape)
angle_valid_data = np.array(valid_dataset['inc_angle']).reshape(-1, 1)
print ("angle shape :", angle_valid_data.shape)
is_iceberg_valid_data = np.array(valid_dataset["is_iceberg"]).reshape(-1, 1)
print ("is_iceberg shape :", is_iceberg_valid_data.shape)  

display_ice_berg(band_1_train_data, band_2_train_data, angle_train_data, is_iceberg_train_data, 100, suptitle= "display the bain image of train data ")
  
del valid_dataset
del train_dataset
gc.collect()
# Out:
# === Train Dataset ===
# band 1 shape : (1271, 75, 75, 1)
# band 2 shape : (1271, 75, 75, 1)
# angle shape : (1271, 1)
# is_iceberg shape : (1271, 1)
# === Test Dataset ===
# band 1 shape : (200, 75, 75, 1)
# band 2 shape : (200, 75, 75, 1)
# angle shape : (200, 1)
# is_iceberg shape : (200, 1)
# 1028

# %%
# Test Data Band 1 and Band 2 Image
band_1_test_data = np.array([np.array(data).astype(np.float32).reshape(75, 75, 1) for data in test_data['band_1']])
print ("band 1 shape :", band_1_test_data.shape)
band_2_test_data = np.array([np.array(data).astype(np.float32).reshape(75, 75, 1) for data in test_data['band_2']])
print ("band 2 shape :", band_2_test_data.shape)
angle_test_data = np.array(test_data['inc_angle']).reshape(-1, 1)
print ("angle shape :", angle_test_data.shape)
id_test_data = np.array(test_data['id'])
print ("id shape :", id_test_data.shape)

band_1_test_data, band_2_test_data, angle_test_data = normalization_data(band_1_test_data, band_2_test_data, angle_test_data, IS_ENABLE_NORMALIZATION)

del test_data
gc.collect()

display_ice_berg(band_1_test_data, band_2_test_data, angle_test_data, None, 200, suptitle = "display the bain image of test data")
# Out:
# band 1 shape : (8424, 75, 75, 1)
# band 2 shape : (8424, 75, 75, 1)
# angle shape : (8424, 1)
# id shape : (8424,)

# %% [markdown]
# # **三、使用資料增強 (data augmentation)的方法來增加訓練資料**

# %%
import math
import random
import numpy as np 
from keras.preprocessing.image import ImageDataGenerator 

def data_generator(band_1, band_2, angle, is_ice_berg, batch_size, shuffle = True, sample_rate = 1.0, normalization = False, concatenate_img = True , reset_count = 100, is_augment = True):
    
    # 執行進行正規化的函式
    band_1, band_2, angle = normalization_data (band_1, band_2, angle, normalization)
    
    # 設定新增訓練影像的相關參數
    if is_augment:    
      band_augmentation = ImageDataGenerator(height_shift_range=[-8,8], width_shift_range=[-8,8], rotation_range=270)
    else:
      band_augmentation = ImageDataGenerator()
    
    # 每次取樣多少比例的總樣本進行訓練
    sample_data_len = (int) (is_ice_berg.shape[0] * sample_rate)
    
    # 依據批次訓練的樣本數計算最少需要的批次的次數
    batch_count = math.floor(sample_data_len / batch_size)
    
    # 實際可整除批次訓練數量的樣本數
    sample_data_len = batch_count * batch_size
    
    # 建立訓練資料的引索值        
    shuffle_data_index = np.arange(is_ice_berg.shape[0])
    
    #np.random.seed()  
    
    use_generate_data_count = 0       
    
    while True: 
      # 重新排列資料索引順序
      if shuffle:
          np.random.shuffle(shuffle_data_index)           
     
      # 依據批次訓練的數量reshape資料索引的格式
      data_index = shuffle_data_index[0:batch_size * batch_count].reshape(-1,batch_size)  
      
       # 針對band 1 及band 2進行影像處理的動作
      if use_generate_data_count <= 0:
        use_generate_data_count = reset_count
        random_seed = np.random.np.random.randint(0, 1024)
        band_1_augmentation = band_augmentation.flow(band_1, batch_size = band_1.shape[0], shuffle = False, seed = 23)
        band_2_augmentation = band_augmentation.flow(band_2, batch_size = band_2.shape[0], shuffle = False, seed = 23)  
        
        # 取出影像處理後的圖片
        band_1_augment_data = next(band_1_augmentation)
        band_2_augment_data = next(band_2_augmentation)
      else:   
        use_generate_data_count = use_generate_data_count - 1
      
      # 建立訓練的批次資料
      batch_band_1 = np.zeros(shape=(batch_size, band_1[0].shape[0], band_1[0].shape[1] ,1 ))
      batch_band_2 = np.zeros(shape=(batch_size, band_1[0].shape[0], band_1[0].shape[1] ,1 ))
      batch_band_3 = np.zeros(shape=(batch_size, band_1[0].shape[0], band_1[0].shape[1] ,1 ))
      batch_angle = np.zeros(shape=(batch_size,1))
      batch_is_iceberg = np.zeros(shape=(batch_size,1))
           
      for epoch_index in range(batch_count): 
        for i in range(2):
          if i == 0:
            # 依據打亂後的順序回傳未經過影像處理的訓練資料            
            for i, index in enumerate(data_index[epoch_index]):            
              batch_band_1[i]= band_1[index]      
              batch_band_2[i] = band_2[index]  
              batch_band_3[i] = np.maximum(batch_band_1[i], batch_band_2[i])
              batch_angle[i] = angle[index]
              batch_is_iceberg[i] = is_ice_berg[index]
          else:
            # 依據打亂後的順序回傳經過影像處理的訓練資料
            for i, index in enumerate(data_index[epoch_index]):            
              batch_band_1[i]= band_1_augment_data[index] 
              batch_band_2[i] = band_2_augment_data[index]
              batch_band_3[i] = np.maximum(batch_band_1[i], batch_band_2[i])
              batch_angle[i] = angle[index]
              batch_is_iceberg[i] = is_ice_berg[index]
            
          if concatenate_img:
            # band_concatenate = np.concatenate([batch_band_1, batch_band_2], axis=-1) 
            band_concatenate = np.concatenate([batch_band_1, batch_band_2, batch_band_3], axis=-1) 
            yield [band_concatenate, batch_angle], [batch_is_iceberg]
          else:
            yield [batch_band_1, batch_band_2, batch_angle], [batch_is_iceberg]
# Out:
# Using TensorFlow backend.

# %%
try:
  del train_gen
  del valid_gen
except Exception:
  pass
finally:
  train_gen = data_generator(band_1_train_data, band_2_train_data, angle_train_data, is_iceberg_train_data, 16, normalization = IS_ENABLE_NORMALIZATION, shuffle=True, sample_rate = 1.0, concatenate_img = False) 
  valid_gen = data_generator(band_1_valid_data, band_2_valid_data, angle_valid_data, is_iceberg_valid_data, 64, normalization = IS_ENABLE_NORMALIZATION, shuffle=True, sample_rate = 1.0, concatenate_img = False)

# %%
x, y = next(train_gen) 
#print (x[0][0][0][0])
print(x[0][0][0][0], x[1][0][0][0], x[2][0], y[0][0])
display_ice_berg(x[0], x[1], x[2], y[0], suptitle='the trann data by data augmetation')

x, y = next(valid_gen) 
print(x[0][0][0][0], x[1][0][0][0], x[2][0], y[0][0])
display_ice_berg(x[0], x[1], x[2], y[0], suptitle="the valid data by data augmentation")
# Out:
# [0.38227442] [0.37123311] [0.23286944] [0.]
# [0.42321917] [0.39059919] [0.17430889] [1.]

# %% [markdown]
# # **四、建立訓練模型**

# %%
 
import keras.layers as KL
import keras.models as KM
import tensorflow as tf
#import keras.backend as K
import keras
from keras.layers import MaxPooling2D, GlobalAveragePooling2D
 
def customized_model(connected_layer_style = 1, connected_node = 8):
  # 75 X 75
  input_image = keras.Input (shape=[IMAGE_WIDTH, IMAGE_HEIGHT, 3], dtype='float32') # image 

  x_11 = KL.Conv2D(16, (1, 1), padding='same', strides = 1, name='conv2d_lv1_11_1')(input_image)
  x_11 = KL.BatchNormalization()(x_11) 

  x_13 = KL.Conv2D(16, (3, 3), padding='same', strides = 1, name='conv2d_lv1_33_1')(input_image)
  x_13 = KL.BatchNormalization()(x_13)
 
  x_15 = KL.Conv2D(16, (5, 5), padding='same', strides = 1, name='conv2d_lv1_55_1')(input_image)
  x_15 = KL.BatchNormalization()(x_15)
  
  x =  KL.Concatenate()([x_11, x_13, x_15])  
  head = KL.Activation('relu')(x)  
  
  for i in range(4):
    x = KL.Conv2D(32, (1,1), padding='same', strides = 1) (head)
    x = KL.BatchNormalization()(x)
    x = KL.Activation('relu')(x)
  
    x = KL.Conv2D(connected_node, (3,3), padding='same', strides = (2,2))(x)
    x = KL.BatchNormalization()(x) 
 
    head = KL.Conv2D(connected_node, (1,1), padding='same', strides =(2,2)) (head)
    head = KL.BatchNormalization()(head)
  
    x = KL.Add()([x, head])
    head = KL.Activation('relu')(x)    
    head = KL.Dropout(0,5)(head)  
  
  if connected_layer_style == 1:   
    # 取每一个特征图的平均值作为输出，用以替代全连接层  
    x = KL.GlobalAveragePooling2D(name='glb_avg_pool')(head)  # shape=(?, 16) 
  elif connected_layer_style == 2: 
    x = KL.GlobalMaxPooling2D(name='glb_max_pool')(head)
  else:
    x = KL.Flatten()(head)    
    x = KL.Dense(connected_node, activation='relu')(x)
  
  input_angle = keras.Input (shape=[1], dtype='float32') # inc angle 

  angle_x = KL.Dense(connected_node, activation='relu')(input_angle)  
   
  # add angle  
  x = KL.Add()([x, angle_x])  

  merge_output = KL.Dense(1, activation='sigmoid')(x)

  model = KM.Model (inputs = [input_image, input_angle], outputs = [merge_output], name='predict_iceberg')
 
  optimizer_adm = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.2)

  #model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
  model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
  
  model.summary()
  return model

# %%
from keras.applications.resnet50 import ResNet50
from keras.applications.vgg16 import VGG16
import keras.layers as KL

def use_classic_network(connected_node = 8 , use_model = 1):
  
  if use_model == 1:
    classic_net = ResNet50(include_top=False, input_tensor = None, weights="imagenet", input_shape= [IMAGE_HEIGHT , IMAGE_WIDTH, 3])
  else:
    classic_net = VGG16(include_top=False, input_tensor = None, weights="imagenet", input_shape=[IMAGE_HEIGHT , IMAGE_WIDTH, 3])
    
  x = classic_net.output
  x = KL.Flatten()(x)
  
  x = KL.Dropout(0.5)(x)
  x = KL.Dense(1024, activation='relu')(x)
  x = KL.Dropout(0.5)(x)  
  x = KL.Dense(connected_node, activation='relu')(x)
    
  input_angle = keras.Input (shape=[1], dtype='float32') # inc angle 

  angle_x = KL.Dense(connected_node, activation='relu')(input_angle)  
   
  # add angle  
  x = KL.Add()([x, angle_x])  
  
  merge_output = KL.Dense(1, activation='sigmoid')(x)

  model = KM.Model (inputs = [classic_net.input, input_angle], outputs = [merge_output], name='predict_iceberg')
 
  optimizer_adm = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.2)

  #model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
  model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
  
  model.summary()
  return model

# %%
from keras.callbacks import ModelCheckpoint,CSVLogger, ReduceLROnPlateau, EarlyStopping

NAME = "ice_berg"

np.random.seed(2321)  

# load mode 

model = customized_model(connected_layer_style=1, connected_node=16)
 
#model = use_classic_network(use_model = 0)
  
log_dir = os.path.join( path.abspath("."), "log")

# Path to save after each epoch. Include placeholders that get filled by Keras.
save_model_path = os.path.join(log_dir, "{}_*epoch*_*loss*.h5".format(NAME.lower()))    
save_model_path = save_model_path.replace("*epoch*", "{epoch:04d}")
save_model_path = save_model_path.replace("*loss*", "{val_loss:04f}") 

save_log_path = os.path.join(log_dir, "{}_loss.csv".format(NAME.lower()))
if os.path.exists(save_log_path):
  os.remove(save_log_path)
  
#earlystop = EarlyStopping(monitor='val_loss', patience=50, mode='auto')
reducelr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, mode='auto', min_delta=0.001, cooldown=0, min_lr=0.00001)  
msave = ModelCheckpoint(save_model_path, monitor='val_loss', mode='min', save_best_only=True, save_weights_only=False)
csv = CSVLogger(save_log_path, append=True)

train_gen = data_generator(band_1_train_data, band_2_train_data, angle_train_data, is_iceberg_train_data, 16, is_augment=True, \
                           normalization=IS_ENABLE_NORMALIZATION, shuffle=True, sample_rate = 1.0, concatenate_img = True) 
valid_gen = data_generator(band_1_valid_data, band_2_valid_data, angle_valid_data, is_iceberg_valid_data, 16, is_augment=True, \
                           normalization=IS_ENABLE_NORMALIZATION, shuffle=True, sample_rate = 1.0, concatenate_img = True)

model.fit_generator(
            train_gen ,
            initial_epoch = 0,
            epochs = 1000,
            steps_per_epoch= 100,
            callbacks = [csv, msave, reducelr], #earlystop
            validation_data = valid_gen,
            validation_steps = 20,
            max_queue_size = 100,
            workers = 0,
            use_multiprocessing=True)

del train_gen
del valid_gen
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0624 09:05:44.414353 140317753034624 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0624 09:05:44.451431 140317753034624 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0624 09:05:44.458173 140317753034624 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0624 09:05:44.495481 140317753034624 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0624 09:05:44.496579 140317753034624 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0624 09:05:47.275299 140317753034624 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0624 09:05:49.804991 140317753034624 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0624 09:05:49.831867 140317753034624 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 75, 75, 3)    0
# __________________________________________________________________________________________________
# conv2d_lv1_11_1 (Conv2D)        (None, 75, 75, 16)   64          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_lv1_33_1 (Conv2D)        (None, 75, 75, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_lv1_55_1 (Conv2D)        (None, 75, 75, 16)   1216        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 75, 75, 16)   64          conv2d_lv1_11_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 75, 75, 16)   64          conv2d_lv1_33_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 75, 75, 16)   64          conv2d_lv1_55_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 75, 75, 48)   0           batch_normalization_1[0][0]
#                                                                  batch_normalization_2[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 75, 75, 48)   0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 75, 75, 32)   1568        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 75, 75, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 75, 75, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 38, 38, 16)   4624        activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 38, 38, 16)   784         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 38, 38, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 38, 38, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 38, 38, 16)   0           batch_normalization_5[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 38, 38, 16)   0           add_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 38, 38, 16)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 38, 38, 32)   544         dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 38, 38, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 38, 38, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 19, 19, 16)   4624        activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 19, 19, 16)   272         dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 19, 19, 16)   64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 19, 19, 16)   64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 19, 19, 16)   0           batch_normalization_8[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 19, 19, 16)   0           add_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 19, 19, 16)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 19, 19, 32)   544         dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 19, 19, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 19, 19, 32)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 10, 10, 16)   4624        activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 10, 10, 16)   272         dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 10, 10, 16)   64          conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 10, 10, 16)   64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 10, 10, 16)   0           batch_normalization_11[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 10, 10, 16)   0           add_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 10, 10, 16)   0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 10, 10, 32)   544         dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 10, 10, 32)   128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 10, 10, 32)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 5, 5, 16)     4624        activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 5, 5, 16)     272         dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 5, 5, 16)     64          conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 5, 5, 16)     64          conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 5, 5, 16)     0           batch_normalization_14[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 5, 5, 16)     0           add_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 5, 5, 16)     0           activation_9[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# glb_avg_pool (GlobalAveragePool (None, 16)           0           dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 16)           32          input_2[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16)           0           glb_avg_pool[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            17          add_5[0][0]
# ==================================================================================================
# Total params: 26,289
# Trainable params: 25,681
# Non-trainable params: 608
# __________________________________________________________________________________________________
# Epoch 1/1000
# 100/100 [==============================] - 10s 101ms/step - loss: 0.6383 - acc: 0.6531 - val_loss: 0.8645 - val_acc: 0.4000
# Epoch 2/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.6201 - acc: 0.6431 - val_loss: 3.5175 - val_acc: 0.4375
# Epoch 3/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.5672 - acc: 0.7050 - val_loss: 0.8178 - val_acc: 0.4062
# Epoch 4/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.5414 - acc: 0.7169 - val_loss: 1.1045 - val_acc: 0.4562
# Epoch 5/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.5263 - acc: 0.7369 - val_loss: 0.6060 - val_acc: 0.7344
# Epoch 6/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.5019 - acc: 0.7569 - val_loss: 8.9657 - val_acc: 0.4437
# Epoch 7/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.4420 - acc: 0.8031 - val_loss: 9.3686 - val_acc: 0.4188
# Epoch 8/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.4385 - acc: 0.8037 - val_loss: 1.2364 - val_acc: 0.4594
# Epoch 9/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.4049 - acc: 0.8244 - val_loss: 6.8752 - val_acc: 0.5687
# Epoch 10/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.4222 - acc: 0.8069 - val_loss: 5.3475 - val_acc: 0.4437
# Epoch 11/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.3981 - acc: 0.8287 - val_loss: 9.3730 - val_acc: 0.3844
# Epoch 12/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 0.3636 - acc: 0.8481 - val_loss: 3.8305 - val_acc: 0.6531
# Epoch 13/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3424 - acc: 0.8519 - val_loss: 6.2773 - val_acc: 0.6062
# Epoch 14/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3524 - acc: 0.8556 - val_loss: 8.3396 - val_acc: 0.4188
# Epoch 15/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.3363 - acc: 0.8556 - val_loss: 5.1537 - val_acc: 0.6062
# Epoch 16/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.3147 - acc: 0.8625 - val_loss: 0.5454 - val_acc: 0.8313
# Epoch 17/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 0.2996 - acc: 0.8806 - val_loss: 0.4132 - val_acc: 0.8125
# Epoch 18/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2958 - acc: 0.8838 - val_loss: 0.2918 - val_acc: 0.8906
# Epoch 19/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2759 - acc: 0.8919 - val_loss: 0.9182 - val_acc: 0.7781
# Epoch 20/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2996 - acc: 0.8806 - val_loss: 0.3126 - val_acc: 0.8719
# Epoch 21/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2717 - acc: 0.8888 - val_loss: 0.2909 - val_acc: 0.8969
# Epoch 22/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2827 - acc: 0.8856 - val_loss: 0.4042 - val_acc: 0.7688
# Epoch 23/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2709 - acc: 0.8956 - val_loss: 0.3060 - val_acc: 0.8938
# Epoch 24/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2511 - acc: 0.8969 - val_loss: 0.3626 - val_acc: 0.8562
# Epoch 25/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2785 - acc: 0.8900 - val_loss: 0.3576 - val_acc: 0.8438
# Epoch 26/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2593 - acc: 0.9025 - val_loss: 0.3210 - val_acc: 0.8500
# Epoch 27/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2741 - acc: 0.8900 - val_loss: 0.3556 - val_acc: 0.8406
# Epoch 28/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2758 - acc: 0.8844 - val_loss: 0.3814 - val_acc: 0.8219
# Epoch 29/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2341 - acc: 0.9100 - val_loss: 0.2409 - val_acc: 0.9125
# Epoch 30/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2609 - acc: 0.8956 - val_loss: 0.3152 - val_acc: 0.8719
# Epoch 31/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2480 - acc: 0.9050 - val_loss: 0.3262 - val_acc: 0.8594
# Epoch 32/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2584 - acc: 0.8981 - val_loss: 0.2472 - val_acc: 0.9156
# Epoch 33/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2391 - acc: 0.9100 - val_loss: 0.3151 - val_acc: 0.8594
# Epoch 34/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2810 - acc: 0.8863 - val_loss: 0.3372 - val_acc: 0.8500
# Epoch 35/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2524 - acc: 0.8931 - val_loss: 0.2624 - val_acc: 0.8969
# Epoch 36/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2440 - acc: 0.9100 - val_loss: 0.3152 - val_acc: 0.8688
# Epoch 37/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2294 - acc: 0.9113 - val_loss: 0.2988 - val_acc: 0.8719
# Epoch 38/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2578 - acc: 0.9000 - val_loss: 0.3060 - val_acc: 0.8750
# Epoch 39/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2683 - acc: 0.8937 - val_loss: 0.2799 - val_acc: 0.8875
# Epoch 40/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2512 - acc: 0.9012 - val_loss: 0.2999 - val_acc: 0.8750
# Epoch 41/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2455 - acc: 0.9044 - val_loss: 0.3170 - val_acc: 0.8844
# Epoch 42/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2556 - acc: 0.8969 - val_loss: 0.2919 - val_acc: 0.8875
# Epoch 43/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2510 - acc: 0.9044 - val_loss: 0.3051 - val_acc: 0.8719
# Epoch 44/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2572 - acc: 0.9000 - val_loss: 0.2872 - val_acc: 0.8875
# Epoch 45/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2627 - acc: 0.8888 - val_loss: 0.2857 - val_acc: 0.8844
# Epoch 46/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2461 - acc: 0.9056 - val_loss: 0.3241 - val_acc: 0.8625
# Epoch 47/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2525 - acc: 0.9044 - val_loss: 0.2819 - val_acc: 0.9031
# Epoch 48/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2460 - acc: 0.9075 - val_loss: 0.3076 - val_acc: 0.8562
# Epoch 49/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2421 - acc: 0.9056 - val_loss: 0.2898 - val_acc: 0.8938
# Epoch 50/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2411 - acc: 0.9056 - val_loss: 0.2945 - val_acc: 0.8812
# Epoch 51/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2632 - acc: 0.9006 - val_loss: 0.3317 - val_acc: 0.8375
# Epoch 52/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2309 - acc: 0.9094 - val_loss: 0.3278 - val_acc: 0.8625
# Epoch 53/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2623 - acc: 0.8981 - val_loss: 0.2532 - val_acc: 0.8906
# Epoch 54/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2303 - acc: 0.9188 - val_loss: 0.2751 - val_acc: 0.8812
# Epoch 55/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 0.2521 - acc: 0.9106 - val_loss: 0.3130 - val_acc: 0.8594
# Epoch 56/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 0.2516 - acc: 0.9038 - val_loss: 0.2438 - val_acc: 0.8969
# Epoch 57/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 0.2368 - acc: 0.9087 - val_loss: 0.3274 - val_acc: 0.8625
# Epoch 58/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2428 - acc: 0.9038 - val_loss: 0.3071 - val_acc: 0.8844
# Epoch 59/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2452 - acc: 0.9038 - val_loss: 0.2635 - val_acc: 0.8844
# Epoch 60/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2448 - acc: 0.9038 - val_loss: 0.3109 - val_acc: 0.8812
# Epoch 61/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2399 - acc: 0.9150 - val_loss: 0.2879 - val_acc: 0.8906
# Epoch 62/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2532 - acc: 0.8950 - val_loss: 0.3174 - val_acc: 0.8562
# Epoch 63/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2345 - acc: 0.9100 - val_loss: 0.3194 - val_acc: 0.8625
# Epoch 64/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2409 - acc: 0.9050 - val_loss: 0.2821 - val_acc: 0.8781
# Epoch 65/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2228 - acc: 0.9137 - val_loss: 0.2557 - val_acc: 0.8938
# Epoch 66/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2443 - acc: 0.9075 - val_loss: 0.3028 - val_acc: 0.8781
# Epoch 67/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2476 - acc: 0.9012 - val_loss: 0.2799 - val_acc: 0.8750
# Epoch 68/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2488 - acc: 0.8988 - val_loss: 0.3340 - val_acc: 0.8469
# Epoch 69/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2324 - acc: 0.9150 - val_loss: 0.2745 - val_acc: 0.8906
# Epoch 70/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2479 - acc: 0.9019 - val_loss: 0.3297 - val_acc: 0.8438
# Epoch 71/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2513 - acc: 0.8988 - val_loss: 0.2638 - val_acc: 0.9031
# Epoch 72/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2336 - acc: 0.9119 - val_loss: 0.2963 - val_acc: 0.8625
# Epoch 73/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2476 - acc: 0.9069 - val_loss: 0.2906 - val_acc: 0.8781
# Epoch 74/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2234 - acc: 0.9225 - val_loss: 0.2715 - val_acc: 0.8969
# Epoch 75/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2540 - acc: 0.9000 - val_loss: 0.3272 - val_acc: 0.8656
# Epoch 76/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2312 - acc: 0.9156 - val_loss: 0.2309 - val_acc: 0.9094
# Epoch 77/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2428 - acc: 0.9094 - val_loss: 0.3270 - val_acc: 0.8531
# Epoch 78/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2270 - acc: 0.9137 - val_loss: 0.2896 - val_acc: 0.8781
# Epoch 79/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 0.2490 - acc: 0.8988 - val_loss: 0.2904 - val_acc: 0.8719
# Epoch 80/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2675 - acc: 0.8950 - val_loss: 0.2754 - val_acc: 0.8875
# Epoch 81/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2269 - acc: 0.9131 - val_loss: 0.3042 - val_acc: 0.9062
# Epoch 82/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2325 - acc: 0.9044 - val_loss: 0.2890 - val_acc: 0.8594
# Epoch 83/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2428 - acc: 0.9113 - val_loss: 0.2887 - val_acc: 0.8719
# Epoch 84/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2488 - acc: 0.9100 - val_loss: 0.2928 - val_acc: 0.8844
# Epoch 85/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2349 - acc: 0.9175 - val_loss: 0.3175 - val_acc: 0.8812
# Epoch 86/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2395 - acc: 0.9038 - val_loss: 0.2864 - val_acc: 0.8625
# Epoch 87/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2431 - acc: 0.9113 - val_loss: 0.2688 - val_acc: 0.8844
# Epoch 88/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2351 - acc: 0.9087 - val_loss: 0.3098 - val_acc: 0.8875
# Epoch 89/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2408 - acc: 0.9044 - val_loss: 0.2873 - val_acc: 0.8750
# Epoch 90/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2316 - acc: 0.9163 - val_loss: 0.2952 - val_acc: 0.8750
# Epoch 91/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2393 - acc: 0.9031 - val_loss: 0.2869 - val_acc: 0.8906
# Epoch 92/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2314 - acc: 0.9163 - val_loss: 0.3069 - val_acc: 0.8625
# Epoch 93/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2353 - acc: 0.9081 - val_loss: 0.2733 - val_acc: 0.8906
# Epoch 94/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2324 - acc: 0.9113 - val_loss: 0.3117 - val_acc: 0.8594
# Epoch 95/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2400 - acc: 0.9125 - val_loss: 0.2696 - val_acc: 0.8938
# Epoch 96/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2491 - acc: 0.9056 - val_loss: 0.3142 - val_acc: 0.8656
# Epoch 97/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2212 - acc: 0.9206 - val_loss: 0.2659 - val_acc: 0.8938
# Epoch 98/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2417 - acc: 0.9019 - val_loss: 0.3005 - val_acc: 0.8875
# Epoch 99/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2194 - acc: 0.9188 - val_loss: 0.2850 - val_acc: 0.8969
# Epoch 100/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2517 - acc: 0.9006 - val_loss: 0.3013 - val_acc: 0.8438
# Epoch 101/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2237 - acc: 0.9163 - val_loss: 0.2979 - val_acc: 0.8812
# Epoch 102/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2188 - acc: 0.9213 - val_loss: 0.2763 - val_acc: 0.9031
# Epoch 103/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2393 - acc: 0.9050 - val_loss: 0.3016 - val_acc: 0.8781
# Epoch 104/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2400 - acc: 0.9038 - val_loss: 0.2607 - val_acc: 0.9031
# Epoch 105/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2210 - acc: 0.9237 - val_loss: 0.3299 - val_acc: 0.8500
# Epoch 106/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2300 - acc: 0.9031 - val_loss: 0.2707 - val_acc: 0.8969
# Epoch 107/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2368 - acc: 0.9081 - val_loss: 0.2963 - val_acc: 0.8688
# Epoch 108/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2335 - acc: 0.9113 - val_loss: 0.3217 - val_acc: 0.8656
# Epoch 109/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 0.2280 - acc: 0.9131 - val_loss: 0.2841 - val_acc: 0.8812
# Epoch 110/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 0.2337 - acc: 0.9125 - val_loss: 0.3107 - val_acc: 0.8562
# Epoch 111/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2272 - acc: 0.9188 - val_loss: 0.2459 - val_acc: 0.8906
# Epoch 112/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2248 - acc: 0.9181 - val_loss: 0.2990 - val_acc: 0.8656
# Epoch 113/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2383 - acc: 0.9044 - val_loss: 0.2866 - val_acc: 0.8812
# Epoch 114/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2149 - acc: 0.9181 - val_loss: 0.3029 - val_acc: 0.8656
# Epoch 115/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2372 - acc: 0.9131 - val_loss: 0.2714 - val_acc: 0.8844
# Epoch 116/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2218 - acc: 0.9200 - val_loss: 0.2836 - val_acc: 0.8812
# Epoch 117/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2158 - acc: 0.9231 - val_loss: 0.3025 - val_acc: 0.8719
# Epoch 118/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2383 - acc: 0.9031 - val_loss: 0.2650 - val_acc: 0.8938
# Epoch 119/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2282 - acc: 0.9137 - val_loss: 0.3020 - val_acc: 0.8750
# Epoch 120/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2388 - acc: 0.9056 - val_loss: 0.2832 - val_acc: 0.8750
# Epoch 121/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2195 - acc: 0.9213 - val_loss: 0.3051 - val_acc: 0.8562
# Epoch 122/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 0.2482 - acc: 0.8969 - val_loss: 0.2773 - val_acc: 0.9000
# Epoch 123/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2333 - acc: 0.9119 - val_loss: 0.3173 - val_acc: 0.8469
# Epoch 124/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2232 - acc: 0.9169 - val_loss: 0.2843 - val_acc: 0.8844
# Epoch 125/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2190 - acc: 0.9256 - val_loss: 0.3014 - val_acc: 0.8594
# Epoch 126/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.2200 - acc: 0.9206 - val_loss: 0.2763 - val_acc: 0.8906
# Epoch 127/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2297 - acc: 0.9100 - val_loss: 0.3153 - val_acc: 0.8625
# Epoch 128/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2269 - acc: 0.9156 - val_loss: 0.2983 - val_acc: 0.8844
# Epoch 129/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2359 - acc: 0.9106 - val_loss: 0.2791 - val_acc: 0.8844
# Epoch 130/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 0.2193 - acc: 0.9194 - val_loss: 0.2774 - val_acc: 0.8875
# Epoch 131/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.2458 - acc: 0.9012 - val_loss: 0.3012 - val_acc: 0.8750
# Epoch 132/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2374 - acc: 0.9087 - val_loss: 0.2920 - val_acc: 0.8875
# Epoch 133/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2151 - acc: 0.9169 - val_loss: 0.2940 - val_acc: 0.8844
# Epoch 134/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2166 - acc: 0.9150 - val_loss: 0.2941 - val_acc: 0.8750
# Epoch 135/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2329 - acc: 0.9169 - val_loss: 0.2521 - val_acc: 0.8875
# Epoch 136/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2056 - acc: 0.9269 - val_loss: 0.3342 - val_acc: 0.8781
# Epoch 137/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2203 - acc: 0.9156 - val_loss: 0.2717 - val_acc: 0.8656
# Epoch 138/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2270 - acc: 0.9194 - val_loss: 0.3230 - val_acc: 0.8625
# Epoch 139/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2319 - acc: 0.9100 - val_loss: 0.3010 - val_acc: 0.8938
# Epoch 140/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2388 - acc: 0.9137 - val_loss: 0.3025 - val_acc: 0.8812
# Epoch 141/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2201 - acc: 0.9081 - val_loss: 0.2781 - val_acc: 0.8875
# Epoch 142/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.2320 - acc: 0.9100 - val_loss: 0.2722 - val_acc: 0.8656
# Epoch 143/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2010 - acc: 0.9275 - val_loss: 0.3023 - val_acc: 0.8812
# Epoch 144/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.2266 - acc: 0.9119 - val_loss: 0.3151 - val_acc: 0.8625
# Epoch 145/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.2304 - acc: 0.9144 - val_loss: 0.3156 - val_acc: 0.8719
# Epoch 146/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.2235 - acc: 0.9188 - val_loss: 0.2688 - val_acc: 0.9031
# Epoch 147/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2135 - acc: 0.9244 - val_loss: 0.3363 - val_acc: 0.8438
# Epoch 148/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.2313 - acc: 0.9131 - val_loss: 0.2911 - val_acc: 0.8781
# Epoch 149/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2037 - acc: 0.9231 - val_loss: 0.2909 - val_acc: 0.8906
# Epoch 150/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2189 - acc: 0.9175 - val_loss: 0.2908 - val_acc: 0.8719
# Epoch 151/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2201 - acc: 0.9119 - val_loss: 0.2919 - val_acc: 0.8750
# Epoch 152/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2095 - acc: 0.9244 - val_loss: 0.2688 - val_acc: 0.9000
# Epoch 153/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2410 - acc: 0.9050 - val_loss: 0.3512 - val_acc: 0.8500
# Epoch 154/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2079 - acc: 0.9244 - val_loss: 0.2801 - val_acc: 0.8875
# Epoch 155/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.2303 - acc: 0.9069 - val_loss: 0.2749 - val_acc: 0.8875
# Epoch 156/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2332 - acc: 0.9144 - val_loss: 0.2968 - val_acc: 0.8688
# Epoch 157/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2130 - acc: 0.9194 - val_loss: 0.3018 - val_acc: 0.8750
# Epoch 158/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.2278 - acc: 0.9150 - val_loss: 0.2907 - val_acc: 0.8594
# Epoch 159/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.2401 - acc: 0.9050 - val_loss: 0.3027 - val_acc: 0.8969
# Epoch 160/1000
# 100/100 [==============================] - 4s 37ms/step - loss: 0.2240 - acc: 0.9094 - val_loss: 0.2892 - val_acc: 0.8656
# Epoch 161/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.2114 - acc: 0.9175 - val_loss: 0.2972 - val_acc: 0.8844
# Epoch 162/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2019 - acc: 0.9319 - val_loss: 0.3109 - val_acc: 0.8625
# Epoch 163/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 0.2167 - acc: 0.9181 - val_loss: 0.2958 - val_acc: 0.8875
# Epoch 164/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 0.2215 - acc: 0.9119 - val_loss: 0.2823 - val_acc: 0.8688
# Epoch 165/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 0.1967 - acc: 0.9262 - val_loss: 0.3084 - val_acc: 0.8656
# Epoch 166/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 0.2346 - acc: 0.9119 - val_loss: 0.2666 - val_acc: 0.8875
# Epoch 167/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.2131 - acc: 0.9244 - val_loss: 0.2814 - val_acc: 0.8812
# Epoch 168/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2033 - acc: 0.9194 - val_loss: 0.2917 - val_acc: 0.8781
# Epoch 169/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.2215 - acc: 0.9175 - val_loss: 0.2519 - val_acc: 0.9031
# Epoch 170/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2274 - acc: 0.9219 - val_loss: 0.2881 - val_acc: 0.8875
# Epoch 171/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2135 - acc: 0.9175 - val_loss: 0.2918 - val_acc: 0.8656
# Epoch 172/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.2135 - acc: 0.9062 - val_loss: 0.3150 - val_acc: 0.8688
# Epoch 173/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2296 - acc: 0.9144 - val_loss: 0.2983 - val_acc: 0.8844
# Epoch 174/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2073 - acc: 0.9237 - val_loss: 0.2899 - val_acc: 0.8625
# Epoch 175/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2185 - acc: 0.9169 - val_loss: 0.2908 - val_acc: 0.8750
# Epoch 176/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.2093 - acc: 0.9237 - val_loss: 0.2596 - val_acc: 0.9000
# Epoch 177/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.2168 - acc: 0.9163 - val_loss: 0.3096 - val_acc: 0.8781
# Epoch 178/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.2137 - acc: 0.9163 - val_loss: 0.2853 - val_acc: 0.8656
# Epoch 179/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.2087 - acc: 0.9144 - val_loss: 0.3379 - val_acc: 0.8531
# Epoch 180/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2119 - acc: 0.9281 - val_loss: 0.2866 - val_acc: 0.8938
# Epoch 181/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2149 - acc: 0.9244 - val_loss: 0.2940 - val_acc: 0.8781
# Epoch 182/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2124 - acc: 0.9287 - val_loss: 0.2984 - val_acc: 0.8719
# Epoch 183/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2208 - acc: 0.9137 - val_loss: 0.2907 - val_acc: 0.8844
# Epoch 184/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 0.2068 - acc: 0.9287 - val_loss: 0.2623 - val_acc: 0.8938
# Epoch 185/1000
# 100/100 [==============================] - 3s 28ms/step - loss: 0.2104 - acc: 0.9181 - val_loss: 0.3125 - val_acc: 0.8594
# Epoch 186/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2342 - acc: 0.9100 - val_loss: 0.3074 - val_acc: 0.8625
# Epoch 187/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 0.2072 - acc: 0.9213 - val_loss: 0.2993 - val_acc: 0.8750
# Epoch 188/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.2152 - acc: 0.9237 - val_loss: 0.3133 - val_acc: 0.8625
# Epoch 189/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2063 - acc: 0.9175 - val_loss: 0.2899 - val_acc: 0.8656
# Epoch 190/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2105 - acc: 0.9175 - val_loss: 0.3050 - val_acc: 0.8688
# Epoch 191/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2008 - acc: 0.9287 - val_loss: 0.2771 - val_acc: 0.8844
# Epoch 192/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2180 - acc: 0.9188 - val_loss: 0.2975 - val_acc: 0.8781
# Epoch 193/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2157 - acc: 0.9169 - val_loss: 0.2926 - val_acc: 0.8750
# Epoch 194/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2147 - acc: 0.9237 - val_loss: 0.2838 - val_acc: 0.8594
# Epoch 195/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2195 - acc: 0.9087 - val_loss: 0.3343 - val_acc: 0.8594
# Epoch 196/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2185 - acc: 0.9194 - val_loss: 0.2378 - val_acc: 0.9062
# Epoch 197/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2108 - acc: 0.9137 - val_loss: 0.3482 - val_acc: 0.8469
# Epoch 198/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2096 - acc: 0.9219 - val_loss: 0.2722 - val_acc: 0.8750
# Epoch 199/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.1950 - acc: 0.9356 - val_loss: 0.2982 - val_acc: 0.8688
# Epoch 200/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2253 - acc: 0.9100 - val_loss: 0.3082 - val_acc: 0.8688
# Epoch 201/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2033 - acc: 0.9225 - val_loss: 0.2328 - val_acc: 0.9031
# Epoch 202/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.2182 - acc: 0.9119 - val_loss: 0.3275 - val_acc: 0.8500
# Epoch 203/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2054 - acc: 0.9231 - val_loss: 0.2625 - val_acc: 0.8719
# Epoch 204/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2082 - acc: 0.9219 - val_loss: 0.2992 - val_acc: 0.8656
# Epoch 205/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2078 - acc: 0.9194 - val_loss: 0.3045 - val_acc: 0.8625
# Epoch 206/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2016 - acc: 0.9287 - val_loss: 0.2711 - val_acc: 0.8906
# Epoch 207/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2017 - acc: 0.9313 - val_loss: 0.2843 - val_acc: 0.8750
# Epoch 208/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.2208 - acc: 0.9194 - val_loss: 0.3015 - val_acc: 0.8656
# Epoch 209/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.1985 - acc: 0.9231 - val_loss: 0.2682 - val_acc: 0.8969
# Epoch 210/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2079 - acc: 0.9206 - val_loss: 0.3028 - val_acc: 0.8625
# Epoch 211/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2184 - acc: 0.9156 - val_loss: 0.3282 - val_acc: 0.8500
# Epoch 212/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2060 - acc: 0.9306 - val_loss: 0.2714 - val_acc: 0.8938
# Epoch 213/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2012 - acc: 0.9287 - val_loss: 0.2950 - val_acc: 0.8594
# Epoch 214/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.1881 - acc: 0.9281 - val_loss: 0.2634 - val_acc: 0.8719
# Epoch 215/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2037 - acc: 0.9213 - val_loss: 0.2995 - val_acc: 0.8719
# Epoch 216/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 0.2064 - acc: 0.9250 - val_loss: 0.3120 - val_acc: 0.8656
# Epoch 217/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2036 - acc: 0.9262 - val_loss: 0.3056 - val_acc: 0.8625
# Epoch 218/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.1945 - acc: 0.9281 - val_loss: 0.3302 - val_acc: 0.8625
# Epoch 219/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2156 - acc: 0.9169 - val_loss: 0.2590 - val_acc: 0.8750
# Epoch 220/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.1764 - acc: 0.9412 - val_loss: 0.2990 - val_acc: 0.8656
# Epoch 221/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2179 - acc: 0.9206 - val_loss: 0.3615 - val_acc: 0.8438
# Epoch 222/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2070 - acc: 0.9281 - val_loss: 0.2675 - val_acc: 0.8781
# Epoch 223/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 0.2015 - acc: 0.9262 - val_loss: 0.2919 - val_acc: 0.8625
# Epoch 224/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 0.2074 - acc: 0.9250 - val_loss: 0.3279 - val_acc: 0.8531
# Epoch 225/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2043 - acc: 0.9219 - val_loss: 0.2685 - val_acc: 0.8812
# Epoch 226/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2086 - acc: 0.9250 - val_loss: 0.3139 - val_acc: 0.8625
# Epoch 227/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 0.2132 - acc: 0.9219 - val_loss: 0.2837 - val_acc: 0.8750
# Epoch 228/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.1850 - acc: 0.9350 - val_loss: 0.3153 - val_acc: 0.8531
# Epoch 229/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2015 - acc: 0.9287 - val_loss: 0.3207 - val_acc: 0.8625
# Epoch 230/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2089 - acc: 0.9244 - val_loss: 0.2753 - val_acc: 0.8750
# Epoch 231/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.1892 - acc: 0.9369 - val_loss: 0.3146 - val_acc: 0.8750
# Epoch 232/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.1981 - acc: 0.9256 - val_loss: 0.2712 - val_acc: 0.8750
# Epoch 233/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2130 - acc: 0.9250 - val_loss: 0.3184 - val_acc: 0.8500
# Epoch 234/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2079 - acc: 0.9175 - val_loss: 0.2951 - val_acc: 0.8781
# Epoch 235/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2103 - acc: 0.9213 - val_loss: 0.2932 - val_acc: 0.8719
# Epoch 236/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.1942 - acc: 0.9325 - val_loss: 0.2938 - val_acc: 0.8531
# Epoch 237/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 0.1993 - acc: 0.9206 - val_loss: 0.3077 - val_acc: 0.8750
# Epoch 238/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.1915 - acc: 0.9412 - val_loss: 0.2950 - val_acc: 0.8562
# Epoch 239/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2247 - acc: 0.9056 - val_loss: 0.3186 - val_acc: 0.8562
# Epoch 240/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.1977 - acc: 0.9231 - val_loss: 0.3143 - val_acc: 0.8531
# Epoch 241/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 0.1920 - acc: 0.9294 - val_loss: 0.3034 - val_acc: 0.8656
# Epoch 242/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.1981 - acc: 0.9281 - val_loss: 0.2726 - val_acc: 0.8781
# Epoch 243/1000
# 100/100 [==============================] - 3s 29ms/step - loss: 0.2171 - acc: 0.9150 - val_loss: 0.3195 - val_acc: 0.8375
# Epoch 244/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 0.1945 - acc: 0.9269 - val_loss: 0.2885 - val_acc: 0.8812
# Epoch 245/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.1985 - acc: 0.9225 - val_loss: 0.3118 - val_acc: 0.8594
# Epoch 246/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.1992 - acc: 0.9300 - val_loss: 0.2963 - val_acc: 0.8656
# Epoch 247/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.1995 - acc: 0.9325 - val_loss: 0.2848 - val_acc: 0.8688
# Epoch 248/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.1917 - acc: 0.9325 - val_loss: 0.3300 - val_acc: 0.8406
# Epoch 249/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.2261 - acc: 0.9144 - val_loss: 0.2351 - val_acc: 0.9000
# Epoch 250/1000
# ...
# Epoch 885/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.0520 - acc: 0.9931 - val_loss: 0.4401 - val_acc: 0.8406
# Epoch 886/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0513 - acc: 0.9919 - val_loss: 0.5600 - val_acc: 0.8031
# Epoch 887/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0568 - acc: 0.9919 - val_loss: 0.4365 - val_acc: 0.8094
# Epoch 888/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0546 - acc: 0.9906 - val_loss: 0.4460 - val_acc: 0.8187
# Epoch 889/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0605 - acc: 0.9881 - val_loss: 0.4368 - val_acc: 0.8219
# Epoch 890/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0523 - acc: 0.9919 - val_loss: 0.5650 - val_acc: 0.7781
# Epoch 891/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0546 - acc: 0.9931 - val_loss: 0.3387 - val_acc: 0.8625
# Epoch 892/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0481 - acc: 0.9931 - val_loss: 0.4955 - val_acc: 0.8000
# Epoch 893/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0523 - acc: 0.9956 - val_loss: 0.4338 - val_acc: 0.8469
# Epoch 894/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0513 - acc: 0.9931 - val_loss: 0.4071 - val_acc: 0.8344
# Epoch 895/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0607 - acc: 0.9887 - val_loss: 0.5206 - val_acc: 0.7906
# Epoch 896/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0561 - acc: 0.9894 - val_loss: 0.3937 - val_acc: 0.8469
# Epoch 897/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0547 - acc: 0.9894 - val_loss: 0.4859 - val_acc: 0.8187
# Epoch 898/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0510 - acc: 0.9925 - val_loss: 0.4228 - val_acc: 0.8313
# Epoch 899/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0498 - acc: 0.9931 - val_loss: 0.4613 - val_acc: 0.8000
# Epoch 900/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0585 - acc: 0.9894 - val_loss: 0.4865 - val_acc: 0.8063
# Epoch 901/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0548 - acc: 0.9919 - val_loss: 0.4758 - val_acc: 0.8094
# Epoch 902/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0544 - acc: 0.9906 - val_loss: 0.4472 - val_acc: 0.8344
# Epoch 903/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0620 - acc: 0.9900 - val_loss: 0.3864 - val_acc: 0.8531
# Epoch 904/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0553 - acc: 0.9900 - val_loss: 0.5032 - val_acc: 0.7969
# Epoch 905/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.0482 - acc: 0.9956 - val_loss: 0.3553 - val_acc: 0.8656
# Epoch 906/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0551 - acc: 0.9919 - val_loss: 0.4461 - val_acc: 0.8187
# Epoch 907/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.0486 - acc: 0.9925 - val_loss: 0.4051 - val_acc: 0.8562
# Epoch 908/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.0561 - acc: 0.9881 - val_loss: 0.4702 - val_acc: 0.8094
# Epoch 909/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0534 - acc: 0.9919 - val_loss: 0.4894 - val_acc: 0.8219
# Epoch 910/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0591 - acc: 0.9881 - val_loss: 0.4917 - val_acc: 0.8063
# Epoch 911/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0517 - acc: 0.9919 - val_loss: 0.4198 - val_acc: 0.8219
# Epoch 912/1000
# 100/100 [==============================] - 2s 24ms/step - loss: 0.0473 - acc: 0.9969 - val_loss: 0.4730 - val_acc: 0.8094
# Epoch 913/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0540 - acc: 0.9906 - val_loss: 0.4857 - val_acc: 0.8156
# Epoch 914/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.0596 - acc: 0.9900 - val_loss: 0.4554 - val_acc: 0.8063
# Epoch 915/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0476 - acc: 0.9938 - val_loss: 0.4194 - val_acc: 0.8531
# Epoch 916/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0548 - acc: 0.9919 - val_loss: 0.4628 - val_acc: 0.7937
# Epoch 917/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0561 - acc: 0.9881 - val_loss: 0.4388 - val_acc: 0.8313
# Epoch 918/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.0550 - acc: 0.9894 - val_loss: 0.5018 - val_acc: 0.8031
# Epoch 919/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0486 - acc: 0.9956 - val_loss: 0.4813 - val_acc: 0.8125
# Epoch 920/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0503 - acc: 0.9912 - val_loss: 0.4814 - val_acc: 0.8000
# Epoch 921/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0621 - acc: 0.9838 - val_loss: 0.4260 - val_acc: 0.8656
# Epoch 922/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.0497 - acc: 0.9944 - val_loss: 0.4637 - val_acc: 0.8094
# Epoch 923/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.0513 - acc: 0.9925 - val_loss: 0.5001 - val_acc: 0.8156
# Epoch 924/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0453 - acc: 0.9956 - val_loss: 0.5208 - val_acc: 0.8094
# Epoch 925/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0519 - acc: 0.9906 - val_loss: 0.4274 - val_acc: 0.8375
# Epoch 926/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0488 - acc: 0.9931 - val_loss: 0.4229 - val_acc: 0.8219
# Epoch 927/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0511 - acc: 0.9925 - val_loss: 0.5240 - val_acc: 0.8000
# Epoch 928/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0581 - acc: 0.9887 - val_loss: 0.4128 - val_acc: 0.8313
# Epoch 929/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0501 - acc: 0.9912 - val_loss: 0.4829 - val_acc: 0.8281
# Epoch 930/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0484 - acc: 0.9906 - val_loss: 0.4801 - val_acc: 0.8344
# Epoch 931/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0488 - acc: 0.9912 - val_loss: 0.4786 - val_acc: 0.8063
# Epoch 932/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0520 - acc: 0.9919 - val_loss: 0.5141 - val_acc: 0.8219
# Epoch 933/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0503 - acc: 0.9944 - val_loss: 0.3928 - val_acc: 0.8469
# Epoch 934/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0486 - acc: 0.9912 - val_loss: 0.5515 - val_acc: 0.8063
# Epoch 935/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0504 - acc: 0.9938 - val_loss: 0.4193 - val_acc: 0.8438
# Epoch 936/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0603 - acc: 0.9875 - val_loss: 0.5123 - val_acc: 0.8031
# Epoch 937/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.0519 - acc: 0.9931 - val_loss: 0.4297 - val_acc: 0.8281
# Epoch 938/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.0463 - acc: 0.9938 - val_loss: 0.5020 - val_acc: 0.7969
# Epoch 939/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.0490 - acc: 0.9925 - val_loss: 0.4636 - val_acc: 0.8125
# Epoch 940/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0470 - acc: 0.9931 - val_loss: 0.4160 - val_acc: 0.8375
# Epoch 941/1000
# 100/100 [==============================] - 2s 24ms/step - loss: 0.0432 - acc: 0.9944 - val_loss: 0.4969 - val_acc: 0.8156
# Epoch 942/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0459 - acc: 0.9944 - val_loss: 0.4517 - val_acc: 0.8250
# Epoch 943/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0497 - acc: 0.9912 - val_loss: 0.4509 - val_acc: 0.8313
# Epoch 944/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.0490 - acc: 0.9887 - val_loss: 0.4664 - val_acc: 0.8438
# Epoch 945/1000
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0484 - acc: 0.9938 - val_loss: 0.5675 - val_acc: 0.7719
# Epoch 946/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0503 - acc: 0.9938 - val_loss: 0.4390 - val_acc: 0.8250
# Epoch 947/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0478 - acc: 0.9938 - val_loss: 0.4763 - val_acc: 0.8156
# Epoch 948/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0539 - acc: 0.9900 - val_loss: 0.4713 - val_acc: 0.8219
# Epoch 949/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0445 - acc: 0.9938 - val_loss: 0.4430 - val_acc: 0.8281
# Epoch 950/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.0468 - acc: 0.9944 - val_loss: 0.5274 - val_acc: 0.8031
# Epoch 951/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0469 - acc: 0.9956 - val_loss: 0.4451 - val_acc: 0.8094
# Epoch 952/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0408 - acc: 0.9956 - val_loss: 0.4169 - val_acc: 0.8500
# Epoch 953/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0485 - acc: 0.9938 - val_loss: 0.4977 - val_acc: 0.8063
# Epoch 954/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0517 - acc: 0.9912 - val_loss: 0.4713 - val_acc: 0.8313
# Epoch 955/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0455 - acc: 0.9938 - val_loss: 0.4874 - val_acc: 0.8250
# Epoch 956/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0439 - acc: 0.9931 - val_loss: 0.5674 - val_acc: 0.8000
# Epoch 957/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0474 - acc: 0.9919 - val_loss: 0.4347 - val_acc: 0.8469
# Epoch 958/1000
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0454 - acc: 0.9931 - val_loss: 0.4980 - val_acc: 0.7937
# Epoch 959/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0451 - acc: 0.9956 - val_loss: 0.4060 - val_acc: 0.8594
# Epoch 960/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0457 - acc: 0.9931 - val_loss: 0.4733 - val_acc: 0.8313
# Epoch 961/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.0499 - acc: 0.9912 - val_loss: 0.4831 - val_acc: 0.8250
# Epoch 962/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0439 - acc: 0.9969 - val_loss: 0.4724 - val_acc: 0.7969
# Epoch 963/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0428 - acc: 0.9950 - val_loss: 0.4751 - val_acc: 0.8156
# Epoch 964/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0564 - acc: 0.9869 - val_loss: 0.5051 - val_acc: 0.8094
# Epoch 965/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0505 - acc: 0.9912 - val_loss: 0.4059 - val_acc: 0.8500
# Epoch 966/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0537 - acc: 0.9894 - val_loss: 0.4696 - val_acc: 0.8219
# Epoch 967/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0468 - acc: 0.9938 - val_loss: 0.4875 - val_acc: 0.8063
# Epoch 968/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.0428 - acc: 0.9950 - val_loss: 0.4177 - val_acc: 0.8375
# Epoch 969/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.0440 - acc: 0.9944 - val_loss: 0.5093 - val_acc: 0.8281
# Epoch 970/1000
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0450 - acc: 0.9938 - val_loss: 0.4697 - val_acc: 0.8313
# Epoch 971/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.0431 - acc: 0.9944 - val_loss: 0.4987 - val_acc: 0.8000
# Epoch 972/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0403 - acc: 0.9975 - val_loss: 0.4169 - val_acc: 0.8406
# Epoch 973/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0395 - acc: 0.9950 - val_loss: 0.4009 - val_acc: 0.8406
# Epoch 974/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0470 - acc: 0.9912 - val_loss: 0.5030 - val_acc: 0.8187
# Epoch 975/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0541 - acc: 0.9925 - val_loss: 0.5193 - val_acc: 0.7906
# Epoch 976/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0464 - acc: 0.9944 - val_loss: 0.5696 - val_acc: 0.7750
# Epoch 977/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0489 - acc: 0.9869 - val_loss: 0.4032 - val_acc: 0.8406
# Epoch 978/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0421 - acc: 0.9981 - val_loss: 0.4853 - val_acc: 0.8156
# Epoch 979/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0422 - acc: 0.9938 - val_loss: 0.4626 - val_acc: 0.8406
# Epoch 980/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0431 - acc: 0.9963 - val_loss: 0.4989 - val_acc: 0.8031
# Epoch 981/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0446 - acc: 0.9931 - val_loss: 0.4891 - val_acc: 0.8219
# Epoch 982/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.0360 - acc: 0.9975 - val_loss: 0.3753 - val_acc: 0.8469
# Epoch 983/1000
# 100/100 [==============================] - 2s 24ms/step - loss: 0.0474 - acc: 0.9912 - val_loss: 0.5354 - val_acc: 0.8000
# Epoch 984/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0507 - acc: 0.9900 - val_loss: 0.4036 - val_acc: 0.8688
# Epoch 985/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0434 - acc: 0.9906 - val_loss: 0.4547 - val_acc: 0.8344
# Epoch 986/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0491 - acc: 0.9931 - val_loss: 0.5066 - val_acc: 0.8281
# Epoch 987/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0501 - acc: 0.9925 - val_loss: 0.5054 - val_acc: 0.8094
# Epoch 988/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0438 - acc: 0.9938 - val_loss: 0.4372 - val_acc: 0.8281
# Epoch 989/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0381 - acc: 0.9950 - val_loss: 0.4730 - val_acc: 0.8219
# Epoch 990/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0415 - acc: 0.9963 - val_loss: 0.5245 - val_acc: 0.8031
# Epoch 991/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0398 - acc: 0.9950 - val_loss: 0.4884 - val_acc: 0.8187
# Epoch 992/1000
# 100/100 [==============================] - 3s 25ms/step - loss: 0.0439 - acc: 0.9944 - val_loss: 0.5174 - val_acc: 0.8094
# Epoch 993/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0413 - acc: 0.9950 - val_loss: 0.6181 - val_acc: 0.7750
# Epoch 994/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0407 - acc: 0.9944 - val_loss: 0.4508 - val_acc: 0.8219
# Epoch 995/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0397 - acc: 0.9988 - val_loss: 0.4936 - val_acc: 0.8219
# Epoch 996/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0401 - acc: 0.9963 - val_loss: 0.4792 - val_acc: 0.8156
# Epoch 997/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0501 - acc: 0.9900 - val_loss: 0.4691 - val_acc: 0.8375
# Epoch 998/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0395 - acc: 0.9963 - val_loss: 0.4799 - val_acc: 0.8438
# Epoch 999/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0418 - acc: 0.9938 - val_loss: 0.3862 - val_acc: 0.8469
# Epoch 1000/1000
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0426 - acc: 0.9931 - val_loss: 0.5537 - val_acc: 0.8094

# %% [markdown]
# # **五，載入訓練的最佳模型及分析結果**

# %%
# 設定模型的檔案路徑及載入模型
import os
from keras.models import load_model
#FILE_NAME = "keep/ice_berg_0368_0.212844"
FILE_NAME = "ice_berg_0249_0.258269"
model_path = os.path.join(path.abspath('.'),"log/{}.h5".format(FILE_NAME))

if not path.exists(model_path):   
    print (model_path)    
    raise ValueError ("File is not exists. - {}".format(model_path))

predict_model = load_model(model_path)
predict_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0624 03:14:26.787778 140293486684032 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0624 03:14:26.839555 140293486684032 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0624 03:14:26.901917 140293486684032 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:245: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0624 03:14:26.902918 140293486684032 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0624 03:14:26.904836 140293486684032 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0624 03:14:29.730006 140293486684032 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0624 03:14:34.081397 140293486684032 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0624 03:14:34.094822 140293486684032 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 75, 75, 3)    0
# __________________________________________________________________________________________________
# conv2d_lv1_11_1 (Conv2D)        (None, 75, 75, 16)   64          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_lv1_33_1 (Conv2D)        (None, 75, 75, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_lv1_55_1 (Conv2D)        (None, 75, 75, 16)   1216        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 75, 75, 16)   64          conv2d_lv1_11_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 75, 75, 16)   64          conv2d_lv1_33_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 75, 75, 16)   64          conv2d_lv1_55_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 75, 75, 48)   0           batch_normalization_1[0][0]
#                                                                  batch_normalization_2[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 75, 75, 48)   0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 75, 75, 32)   1568        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 75, 75, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 75, 75, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 38, 38, 16)   4624        activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 38, 38, 16)   784         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 38, 38, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 38, 38, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 38, 38, 16)   0           batch_normalization_5[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 38, 38, 16)   0           add_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 38, 38, 16)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 38, 38, 32)   544         dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 38, 38, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 38, 38, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 19, 19, 16)   4624        activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 19, 19, 16)   272         dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 19, 19, 16)   64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 19, 19, 16)   64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 19, 19, 16)   0           batch_normalization_8[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 19, 19, 16)   0           add_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 19, 19, 16)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 19, 19, 32)   544         dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 19, 19, 32)   128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 19, 19, 32)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 10, 10, 16)   4624        activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 10, 10, 16)   272         dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 10, 10, 16)   64          conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 10, 10, 16)   64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 10, 10, 16)   0           batch_normalization_11[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 10, 10, 16)   0           add_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 10, 10, 16)   0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 10, 10, 32)   544         dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 10, 10, 32)   128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 10, 10, 32)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 5, 5, 16)     4624        activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 5, 5, 16)     272         dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 5, 5, 16)     64          conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 5, 5, 16)     64          conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 5, 5, 16)     0           batch_normalization_14[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 5, 5, 16)     0           add_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 5, 5, 16)     0           activation_9[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# glb_avg_pool (GlobalAveragePool (None, 16)           0           dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 16)           32          input_2[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16)           0           glb_avg_pool[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            17          add_5[0][0]
# ==================================================================================================
# Total params: 26,289
# Trainable params: 25,681
# Non-trainable params: 608
# __________________________________________________________________________________________________

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import random

from sklearn.metrics import roc_curve, auc

def display_roc_curve(predict_result, target_result, caption="Receiver Operating Characteristic Curve"):  
  fpr, tpr, _ = roc_curve(target_result, predict_result)   
  label_list = "area under curve :{}".format(round(auc(fpr, tpr),2))
  plt.figure()
  plt.plot(fpr, tpr, color='darkorange',lw=2, label= label_list) 
  plt.plot([0.0,1],[0,1], color='navy',lw=2)   
  plt.xlim([0.0, 1.0])  # 設定X軸的刻度
  plt.ylim([0.0, 1.02]) # 設定Y軸的刻度且為了避免1.0的線與圖的外框相連，因此多出0.02
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title(caption)
  plt.legend(loc='lower right') # 設定線段說明的位置
  plt.show()


def display_mulit_roc_curve(dictargs, caption ):  
    plt.figure()
    plt.plot([0.0,1],[0,1], color='navy',lw=2)   
    plt.xlim([0.0, 1.0])  # 設定X軸的刻度
    plt.ylim([0.0, 1.02]) # 設定Y軸的刻度且為了避免1.0的線與圖的外框相連，因此多出0.02
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(caption)
     
    line_color=['darkorange', 'black', 'green', "black", "red", "cyan", "yellow", "magenta"]
    
    for i, key in enumerate(dictargs):
      val = dictargs.get(key)     
      fpr, tpr, _ = roc_curve(val[0], val[1])
      roc_auc = round(auc(fpr, tpr),2)      
      plt.plot(fpr, tpr, color=line_color[i], lw=2, label= "{} auc :{}".format(key,roc_auc)) 
      
    plt.legend(loc='lower right')  
    plt.show()
    
def display_error_image(band_1, band_2, angle, target, predict, display_index, suptitle ="diisplay error image" ):  
  fig, ax = plt.subplots(figsize=(22 , 6))
  fig.subplots_adjust(hspace=0.4, wspace=0.1)   
 
  for i, index in enumerate(display_index):
    if (i >= DISPLAY_IMAGE): break;
    plt.subplot(2, DISPLAY_IMAGE, i + 1)       
    plt.title("band 1:{}-{:.8f}\nangle:{:.8f}".format(target[index][0], predict[index][0], angle[index][0]))
    plt.axis("off")
    plt.imshow(band_1[index].reshape(75,75), cmap="gray")
   
  for i, index in enumerate(display_index): 
    if (i >= DISPLAY_IMAGE): break;
    plt.subplot(2, DISPLAY_IMAGE, i + DISPLAY_IMAGE + 1)      
    plt.title("band 2:{}-{:.8f}\nangle:{:.8f}".format(target[index][0], predict[index][0], angle[index][0] )) 
    plt.axis("off")
    plt.suptitle = suptitle
    plt.imshow(band_2[index].reshape(75,75), cmap="gray")

# %%
# 評估模型
roc_dict ={}
# 評估Train Dataset的loss值及正確率
print ("=== Train Dataset ===")
band_1, band_2, angle = normalization_data(band_1_train_data, band_2_train_data, angle_train_data, IS_ENABLE_NORMALIZATION)
band_3 = np.maximum(band_1, band_2)
band = np.concatenate((band_1, band_2, band_3) ,axis = -1)
predict = predict_model.predict(x=[band, angle])
roc_dict["train"] = (is_iceberg_train_data, predict)
train_data_result = predict_model.evaluate(x=[band, angle], y = is_iceberg_train_data)
print ("loss : ", train_data_result[0])
print ("accuracy :", train_data_result[1])

# 評估Validation Dataset的loss值及正確率
print ("=== Validation Dataset ===")
band_1, band_2, angle = normalization_data(band_1_valid_data, band_2_valid_data, angle_valid_data, IS_ENABLE_NORMALIZATION)
band_3 = np.maximum(band_1, band_2)
band = np.concatenate((band_1,band_2, band_3) ,axis = -1)   
  
predict = predict_model.predict(x=[band, angle])
roc_dict["valid"] = (is_iceberg_valid_data, predict)
valid_data_result = predict_model.evaluate(x= [band, angle], y = is_iceberg_valid_data)
print ("loss : ", valid_data_result[0])
print ("accuracy :", valid_data_result[1])
                                        
                                               
# 建立ROC Curve (Receiver Operating Characteristic Curve)
display_mulit_roc_curve(roc_dict, caption="the ROC curve of train data")
# Out:
# === Train Dataset ===
# 1271/1271 [==============================] - 1s 552us/step
# loss :  0.08979732689193437
# accuracy : 0.982690794649882
# === Validation Dataset ===
# 200/200 [==============================] - 0s 251us/step
# loss :  0.28032473266124724
# accuracy : 0.895

# %%
import seaborn as sn  
from sklearn.metrics import classification_report, confusion_matrix
 
target_names = ['non-iceberg', 'icebert' ]
 
print ("=== the confusion matrix of train data ====")
iceberg_classify = [0 if prob[0] < 0.5 else 1 for prob in roc_dict["train"][1]]      
cm = confusion_matrix(y_true=is_iceberg_train_data, y_pred=iceberg_classify)
print(pd.DataFrame(cm, columns=target_names))
print(classification_report(is_iceberg_train_data, iceberg_classify, target_names=target_names)) 
  
print ("=== the confusion matrix of valid data ====") 
iceberg_classify = [0 if prob[0] < 0.5 else 1 for prob in roc_dict["valid"][1]]
cm = confusion_matrix(y_true=is_iceberg_valid_data, y_pred=iceberg_classify)
print (pd.DataFrame(cm, columns=target_names))
print (classification_report(is_iceberg_valid_data, iceberg_classify, target_names=target_names))
# Out:
# === the confusion matrix of train data ====
#    non-iceberg  icebert
# 0          624       11
# 1           11      625
#               precision    recall  f1-score   support
#
#  non-iceberg       0.98      0.98      0.98       635
#      icebert       0.98      0.98      0.98       636
#
#     accuracy                           0.98      1271
#    macro avg       0.98      0.98      0.98      1271
# weighted avg       0.98      0.98      0.98      1271
#
# === the confusion matrix of valid data ====
#    non-iceberg  icebert
# 0           74        9
# 1           12      105
#               precision    recall  f1-score   support
#
#  non-iceberg       0.86      0.89      0.88        83
#      icebert       0.92      0.90      0.91       117
#
#     accuracy                           0.90       200
#    macro avg       0.89      0.89      0.89       200
# weighted avg       0.90      0.90      0.90       200

# %%
# 顯示錯誤的資料
non_iceberg_false = []
iceberg_false = []
for i, result in enumerate(zip(is_iceberg_valid_data, iceberg_classify)):  
  if result[0] != result[1]:
      if result[0] == 1:
        iceberg_false.append(i) 
      else: 
        non_iceberg_false.append(i) 
        
display_error_image(band_1_train_data, band_2_train_data, angle_valid_data, is_iceberg_valid_data, roc_dict["valid"][1], iceberg_false, suptitle="Iceberg False Image")
display_error_image(band_1_train_data, band_2_train_data, angle_valid_data, is_iceberg_valid_data, roc_dict["valid"][1], non_iceberg_false, suptitle="Non-Iceberg False Image")

# %%
# 使用資料增強的方式產生Test Dataset進行評估loss值及正確率
print ("=== Test Dataset ===")
TEST_ECPOHS = 8

test_gen = data_generator(band_1_valid_data , band_2_valid_data , angle_valid_data , is_iceberg_valid_data, 200, reset_count=1,\
                          shuffle = True, normalization = IS_ENABLE_NORMALIZATION,  sample_rate=1.0, concatenate_img=True)
Average_Loss = 0
Average_Accuracy = 0
roc_dict ={}
total_predict = []
total_target = []
for i in range (TEST_ECPOHS):
  print ("=== Round {} ===".format(i+1))  
  test_data , test_ans = next(test_gen)   
  total_target.extend(test_ans[0])
 
  # 使用predict方法取得判斷的機率值並存至roc_dict字典物件
  predict_result = predict_model.predict(x=[test_data[0], test_data[1]])
  total_predict.extend(predict_result)
  key = "round {}".format(i+1)
  roc_dict[key] = (test_ans[0], predict_result)
  
  # 使用predict方法取得判斷的機率值
  predict_result = predict_model.evaluate(x=[test_data[0], test_data[1]], y=test_ans)  
  print ("loss : ", predict_result[0])
  print ("accuracy :", predict_result[1])
  
  Average_Loss += predict_result[0]
  Average_Accuracy += predict_result[1]

print ("=== Average evaluate ===")
print ("loss : ", Average_Loss / TEST_ECPOHS)
print ("accuracy :",Average_Accuracy / TEST_ECPOHS)

# 建立ROC Curve (Receiver Operating Characteristic Curve)
display_mulit_roc_curve(roc_dict, caption="the roc curve of test data")
# Out:
# === Test Dataset ===
# === Round 1 ===
# 200/200 [==============================] - 0s 352us/step
# loss :  0.2803247421979904
# accuracy : 0.895
# === Round 2 ===
# 200/200 [==============================] - 0s 327us/step
# loss :  0.40660991668701174
# accuracy : 0.805
# === Round 3 ===
# 200/200 [==============================] - 0s 311us/step
# loss :  0.28032474517822265
# accuracy : 0.895
# === Round 4 ===
# 200/200 [==============================] - 0s 290us/step
# loss :  0.4066098976135254
# accuracy : 0.805
# === Round 5 ===
# 200/200 [==============================] - 0s 296us/step
# loss :  0.280324741601944
# accuracy : 0.895
# === Round 6 ===
# 200/200 [==============================] - 0s 290us/step
# loss :  0.40660991191864015
# accuracy : 0.805
# === Round 7 ===
# 200/200 [==============================] - 0s 275us/step
# loss :  0.280324739664793
# accuracy : 0.895
# === Round 8 ===
# 200/200 [==============================] - 0s 289us/step
# loss :  0.40660990357398985
# accuracy : 0.805
# === Average evaluate ===
# loss :  0.34346732480451464
# accuracy : 0.8499999999999999

# %%
import seaborn as sn  
from sklearn.metrics import classification_report, confusion_matrix 
target_names = ['non-iceberg', 'icebert' ] 
print ("=== the confusion matrix of test data ====")
iceberg_classify = [0 if prob[0] < 0.5 else 1  for prob in total_predict ] 
confusion_matrix = confusion_matrix(y_true=total_target, y_pred=iceberg_classify)
print(pd.DataFrame(confusion_matrix, columns=target_names))
print(classification_report(total_target, iceberg_classify, target_names=target_names))
# Out:
# === the confusion matrix of test data ====
#    non-iceberg  icebert
# 0          544      120
# 1          120      816
#               precision    recall  f1-score   support
#
#  non-iceberg       0.82      0.82      0.82       664
#      icebert       0.87      0.87      0.87       936
#
#     accuracy                           0.85      1600
#    macro avg       0.85      0.85      0.85      1600
# weighted avg       0.85      0.85      0.85      1600

# %% [markdown]
# # **六，產生上傳的Submisson檔案**

# %%
import datetime
save_file = "ice_berg_submission_{:%Y%m%d_%H%M}.csv".format(datetime.datetime.now())
print (save_file)
band_3 = np.maximum(band_1_test_data, band_2_test_data)
band = np.concatenate((band_1_test_data,band_2_test_data, band_3) ,axis = -1)

predict_result = predict_model.predict(x=[band, angle_test_data])

save_result = pd.DataFrame()
save_result['id'] = id_test_data.reshape(-1)
save_result['is_iceberg'] = predict_result
save_result.to_csv(save_file, index=False)
print(save_result.head())
# Out:
# ice_berg_submission_20190624_0338.csv
#          id  is_iceberg
# 0  5941774d    0.275987
# 1  4023181e    0.295818
# 2  b20200e4    0.000000
# 3  e7f018bb    0.819459
# 4  4371c8c3    0.000043

# %%
from keras.utils.vis_utils import plot_model

# Create model object in inference mode. inference training
plot_model(model, to_file="iceberg.png", show_shapes=True, show_layer_names=True)
